# %% [markdown]
# 1. Write a program which will find all such numbers which are
# divisible by 7 but are not a multiple of 5, between 2000 and 3200
# (both included). The numbers obtained should be printed in a comma
# -separated sequence on a single line.

# %%
a = []
for i in range(2000,3200):
    if i%7==0:
        print("divisible by 7",i)
    elif i%5==0:
        a.append(i)
        print("divisible by 5",a)
# Out:
# divisible by 5 [2000]
# divisible by 7 2002
# divisible by 5 [2000, 2005]
# divisible by 7 2009
# divisible by 5 [2000, 2005, 2010]
# divisible by 5 [2000, 2005, 2010, 2015]
# divisible by 7 2016
# divisible by 5 [2000, 2005, 2010, 2015, 2020]
# divisible by 7 2023
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025]
# divisible by 7 2030
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035]
# divisible by 7 2037
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040]
# divisible by 7 2044
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040, 2045]
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040, 2045, 2050]
# divisible by 7 2051
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040, 2045, 2050, 2055]
# divisible by 7 2058
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040, 2045, 2050, 2055, 2060]
# divisible by 7 2065
# divisible by 5 [2000, 2005, 2010, 2015, 2020, 2025, 2035, 2040, 2045, 2050, 2055, 2060, 2070]
# ...

# %% [markdown]
# 2. Write a program which can compute the factorial of a given
# numbers. The results should be printed in a comma-separated
# sequence on a single line.
# Suppose the input is supplied to the program: 8
# Then, the output should be: 40320

# %%
x = int(input("enter a number : "))
fac =1
for i in range(x,1,-1):
    fac = fac*i
print("factorial :",fac)
# Out:
# enter a number : 5
# factorial : 120

# %% [markdown]
# 3. With a given integral number n, write a program to generate a dictionary that contains (i, i*i) such that is an integral
# number between 1 and n (both included) and then the program should print the dictionary.
# Suppose the input is supplied to the program: 8
# Then, the output should be: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
x = int(input("enter a number : "))
a = {}
for i in range(x+1):
    a[i] = i*i
print(a)
# Out:
# enter a number : 5
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# 4. Write a program which accepts a sequence of comma-separated numbers from console and generate a list and a tuple which contains every number.
# Suppose the input is supplied to the program: 34, 67, 55, 33, 12, 98

# %%
x = int(input("enter a number : "))
a = []
for i in range(x):
    ad = eval(input("  "))
    a.append(ad)
print(a)
print(tuple(a))
# Out:
# enter a number : 1
#   12
# [12]
# (12,)

# %% [markdown]
# 5. Write a program to swap the key value pair for max and min values
# Eg if the dict is like this {‘a’:1,’b’:2,’c’:3}
# Output should be {a:3,b:2,c:1}

# %%
rangge = int(input("Enter a Range: "))
x = {}
y ={}
for i in range(rangge):
    key= str(input("enter a keys: "))
    value = eval(input("enter a value: "))
    x[key] = value
print("\nOriginal dictionary ",x)
sorted_key = sorted(x.keys())
sorted_value = sorted(y.values(),reverse =True)
for i,j in zip(sorted_key,sorted_value):
    y[i]=j
print("\nRequired Dictionary is :",y)
# Out:
# Enter a Range: 3
# enter a keys: a
# enter a value: 1
# enter a keys: b
# enter a value: 2
# enter a keys: c
# enter a value: 3
#
# Original dictionary  {'a': 1, 'b': 2, 'c': 3}
#
# Required Dictionary is : {}

# %%
rangge = int(input("Enter a Range: "))
x = {}
y ={}
for i in range(rangge):
    key= str(input("enter a keys: "))
    value = eval(input("enter a value: "))
    x[key] = value
sorted_key = sorted(x.keys())
sorted_value = sorted(x.values(),reverse =True)
for i,j in zip(sorted_key,sorted_value):
    y[i]=j
print("\nRequired Dictionary is :",y)
# Out:
# Enter a Range: 3
# enter a keys: a
# enter a value: 1
# enter a keys: b
# enter a value: 2
# enter a keys: c
# enter a value: 3
#
# Required Dictionary is : {'a': 3, 'b': 2, 'c': 1}

# %% [markdown]
# ## 2nd Ans

# %%
keys = str(input("Enter your keys with space separated: ")).split()
values= list(map(int,input("Enter your values with space separated: ").split()))

dict1 = dict(map(lambda x,y: (x,y), keys,values))
print("\nOriginal Dictionary is: ",dict1)

dict2 = dict(map(lambda x,y: (x,y),sorted(keys),sorted(values,reverse=True)))
print("\nRequired Dictionary is:",dict2)

# %% [markdown]
# 6. Write a program that calculates and prints the value according to the given formula:
# Q = Square root of [(2 * C * D)/H]
# Following are the fixed values of C and H: C is 50. H is 30.
# D is the variable whose values should be input to your program in a comma-separated sequence.

# %%
D = int(input("enter a number: "))
C = 50
H = 30
Q = 0.5**2*C*D/H
print(round(Q))
# Out:
# enter a number: 20
# 8

# %% [markdown]
# 7. Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array. The element value in the i-th row and j-th column of the array should be i*j.
# Suppose the following inputs are given to the program: 3, 5
# Then, the output of the program should be: [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]

# %%
import numpy as np

# %%
x = int(input("Enter a number of rows: "))
y = int(input("Enter a number of columns: "))
mat = [[0 for col in range (y)] for row in range (x)]
for row in range(x):
    for col in range(y):
        mat[row][col]=row*col
print(mat,end=" ")
# Out:
# Enter a number of rows: 3
# Enter a number of columns: 5
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]

# %% [markdown]
# 8. Write a program that accepts a comma separated sequence of words as input and prints the words in a comma-separated sequence after sorting them alphabetically.
# Suppose the input is supplied to the program: without, hello, bag, world
# Then, the output should be: bag, hello, without, world

# %%
a = "without", "hello", "bag", "world"
print(sorted(a))
# Out:
# ['bag', 'hello', 'without', 'world']

# %% [markdown]
# 9. Write a program that accepts sequence of lines as input and prints the lines after making all characters in the sentence capitalized.
#
# Suppose the input is supplied to the program: Hello world
# Practice makes perfect
# Then, the output should be: HELLO WORLD
# PRACTICE MAKES PERFECT

# %%
a = "Hello world Practice makes perfect"
print(a.upper())
# Out:
# HELLO WORLD PRACTICE MAKES PERFECT

# %% [markdown]
# 10. Write a program that accepts a sequence of whitespace separated words as input and prints the words after removing all duplicate words and sorting them alphanumerically.
# Suppose the input is supplied to the program: hello world and practice makes perfect and hello world again
# Then, the output should be: again and hello makes perfect practice world

# %%
a = ("hello world and practice makes perfect and hello world again").split()
print(sorted(set(a)))
# Out:
# ['again', 'and', 'hello', 'makes', 'perfect', 'practice', 'world']

# %%
a = "hello world and practice makes perfect and hello world again"
x = [word.lower() for word in a.split()]
x.sort()
print("The sorted words are:")
for word in x:
    print(word)
# Out:
# The sorted words are:
# again
# and
# and
# hello
# hello
# makes
# perfect
# practice
# world
# world

# %% [raw]
# 11. Write a program which takes a input as a string  and print * at all the even indexes
# Suppose the input is supplied to the program: deepanshu
# Then the output should be: *e*p*n*h*.

# %%
a = "deepanshu"
for i in range (len(a)):
    if i%2!=0:
        print(x[i],"*",end=" ")
# Out:
# e * p * n * h *

# %% [raw]
# 12. Write a program, which will find all such numbers between 1000 and 3000 (both included) such that each digit of the number
# is an even number.
# The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
x=[]
for i in range(1000,3000):
    if i%2==0:
        x.append(i)
print(x)
# Out:
# [1000, 1002, 1004, 1006, 1008, 1010, 1012, 1014, 1016, 1018, 1020, 1022, 1024, 1026, 1028, 1030, 1032, 1034, 1036, 1038, 1040, 1042, 1044, 1046, 1048, 1050, 1052, 1054, 1056, 1058, 1060, 1062, 1064, 1066, 1068, 1070, 1072, 1074, 1076, 1078, 1080, 1082, 1084, 1086, 1088, 1090, 1092, 1094, 1096, 1098, 1100, 1102, 1104, 1106, 1108, 1110, 1112, 1114, 1116, 1118, 1120, 1122, 1124, 1126, 1128, 1130, 1132, 1134, 1136, 1138, 1140, 1142, 1144, 1146, 1148, 1150, 1152, 1154, 1156, 1158, 1160, 1162, 1164, 1166, 1168, 1170, 1172, 1174, 1176, 1178, 1180, 1182, 1184, 1186, 1188, 1190, 1192, 1194, 1196, 1198, 1200, 1202, 1204, 1206, 1208, 1210, 1212, 1214, 1216, 1218, 1220, 1222, 1224, 1226, 1228, 1230, 1232, 1234, 1236, 1238, 1240, 1242, 1244, 1246, 1248, 1250, 1252, 1254, 1256, 1258, 1260, 1262, 1264, 1266, 1268, 1270, 1272, 1274, 1276, 1278, 1280, 1282, 1284, 1286, 1288, 1290, 1292, 1294, 1296, 1298, 1300, 1302, 1304, 1306, 1308, 1310, 1312, 1314, 1316, 1318, 1320, 1322, 1324, 1326, 1328, 1330, 1
# ...

# %% [raw]
# 13. Write a program that accepts a sentence and calculate the number of letters and digits.
# Suppose the input is supplied to the program: hello world! 123
# Then, the output should be: LETTERS 10
#      DIGITS 3

# %%
x = input(" Enter a string: ")
d =0
l=0
for i in (x):
    if i.isalpha():
        l+=1
    if i.isdigit():
        d+=1
    else:
        pass
print("number of digit",d)
print("number of alphabates",l)
# Out:
#  Enter a string: "234rd"
# number of digit 3
# number of alphabates 2

# %% [raw]
# 14. Write a program that accepts a sentence and calculate the number of upper case letters and lower case letters.
# Suppose the input is supplied to the program: Hello world!
# Then, the output should be: UPPER CASE 1
#    LOWER CASE 9

# %%
x = "DeePanShu"
a =0
b=0
for i in (x):
    if i.islower():
        a+=1
    if i.isupper():
        b+=1
    else:
        pass
print("count lower case",a)
print("count upper case",b)
# Out:
# count lower case 6
# count upper case 3

# %% [raw]
# 15. Write a program that computes the value of a+aa+aaa+aaaa with a given digit as the value of a.
# Suppose the input is supplied to the program: 9
# Then, the output should be: 11106

# %%
a = int(input("enter a range: "))
sum = 0
for i in range(1,a+1):
    x = eval('9'*i) #we can take a input also
    sum+=x
print(sum)
# Out:
# enter a range: 9
# 1111111101

# %% [raw]
# 16. Use a list comprehension to square each odd number in a list. The list is input by a sequence of comma-separated numbers.
# Suppose the input is supplied to the program: 1,2,3,4,5,6,7,8,9
# Then, the output should be: 1, 3, 5, 7, 9

# %%
lst = [i**2 for i in range(1,10,2)]
lst
# Out:
# [1, 9, 25, 49, 81]

# %% [raw]
# 18
#  You are required to write a program to sort the (name, age, height) tuples by ascending order where name is string, age and height are numbers. The tuples are input by console. The sort criteria is:
# 1: Sort based on name;
# 2: Then sort based on age;
# 3: Then sort by score.
#
# The priority is that name > age > score.
# If the following tuples are given as input to the program:
# Tom,19,80
# John,20,90
# Jony,17,91
# Jony,17,93
# Json,21,85
# Then, the output of the program should be:
# [('John', '20', '90'), ('Jony', '17', '91'), ('Jony', '17', '93'), ('Json', '21', '85'), ('Tom', '19', '80')]

# %%
ranz = int(input("give a range: "))
a=[]

for i in range(ranz):
    x = str(input("enter a name: "))
    y = int(input("enter a age: "))
    z = int(input("enter a height: "))
    b= x,y,z
    a.append(b)
    print(sorted(a))
# Out:
# give a range: 3
# enter a name: "rahul"
# enter a age: 20
# enter a height: 156
# [('"rahul"', 20, 156)]
# enter a name: "ravi"
# enter a age: 34
# enter a height: 157
# [('"rahul"', 20, 156), ('"ravi"', 34, 157)]
# enter a name: "amit"
# enter a age: 16
# enter a height: 123
# [('"amit"', 16, 123), ('"rahul"', 20, 156), ('"ravi"', 34, 157)]

# %% [raw]
# 19. Write a program to compute the frequency of the words from the input. The output should output after sorting the key alphanumerically.
# Suppose the input is supplied to the program:
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3.
# Then, the output should be:
# 2:2
# 3.:1
# 3?:1
# New:1
# Python:5
# Read:1
# and:1
# between:1
# choosing:1
# or:2
# to:1

# %%
d=dict()    #wrong ans
s=input("Enter the range:")
for i in s.split():
    s=input("Enter the string:")
    d[i]=d.get(i,0)+1
    print(d)
    print(sorted(d.items()))
# Out:
# Enter the range:5
# Enter the string:New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3
# {'5': 1}
# [('5', 1)]

# %% [raw]
# 20. u need to lower all the characters in the given string   s = "A man, A plan, A goodman:"
# and remove all non-alphanumeric  characters from the string and check after removing if the string is palindrome or not.

# %%
s = "A man, A plan, A goodman:"
x = []
for i in s[::-1]:
    if i.isalnum():
        x.append(i)
print(x)
# Out:
# ['n', 'a', 'm', 'd', 'o', 'o', 'g', 'A', 'n', 'a', 'l', 'p', 'A', 'n', 'a', 'm', 'A']

# %% [raw]
# 21 L=[“5’2”,”8’9”,”90’4”]  L==[5.2,8.9,90.4]

# %%
L = ["5'2","8'9","90'4"]
x = []

for i in L:
    a=i.replace("'",".")
    x.append(float(a))
print(x)
# Out:
# [5.2, 8.9, 90.4]

# %% [raw]
# 22. Write a Python program that accepts an integer (n) and computes the value of n+nn+nnn.

# %%
x= int(input("enter a range"))
y=0
for i in range(5):
    a = eval('2'*i)
    y+=a
print(y)
# Out:
# enter a range3
# 246

# %%
for i in range(1,6):
    print("2"*i,end='+')
# Out:
# 2+22+222+2222+22222+

# %% [raw]
# 23. Write a program to swap the key value pair for max and min values
# Eg if the dict is like this {‘a’:1,’b’:2,’c’:3}
# Output should be {a:3,b:2,c:1}

# %%
x = int(input(""))
a={}
b = {}
for i in range(x):
    key= str(input("Enter a keys: "))
    value = eval(input("enter a value:  "))
    a[key] = value
short_keys = sorted(a.keys())
short_values = max(key)
for i ,j in zip(short_keys,short_values):
    b[i]=j
print("\n",b)
# Out:
# 3
# Enter a keys: a
# enter a value:  12
# Enter a keys: b
# enter a value:  2
# Enter a keys: c
# enter a value:  12
#
#  {'a': 'c'}

# %% [raw]
# 24 Write a program to compute 1/2+2/3+3/4+...+n/n+1 with a given n input by console (n>0).
#                If the following n is given as input to the program: 5
#               Then, the output of the program should be: 3.5

# %%
x = int(input("enter a number: "))
y = 0
for i in range(1,x+1):
    a =i/(i+1)
    y+=a
print(round(y,2))
# Out:
# enter a number: 5
# 3.55

# %% [raw]
# 25  Please write a program using generator to print the even numbers between 0 and n in comma separated form while n is input
# by console.
# Example: If the following n is given as input to the program: 10
# Then, the output of the program should be: 0,2,4,6,8,10

# %%
#n = int(input().strip())
x = int(input(" enter a number: "))
for i in range(1,11):
    print(x,"*",i,"=",x*i)
# Out:
#  enter a number: 4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
